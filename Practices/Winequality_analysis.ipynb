# %%
import pandas
import numpy as np

# %%
df = pandas.read_csv('../Datasets/winequality-red.csv',sep=";")

# Imprime toda la tabla
df 

# Nombres de las columnas
#print(df.columns)

# Valores de las celdas
#print(df.values)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ## Filtrar filas y columnas

# %%
#print(df.values) # Toda la matriz
print(df.values[:,0]) #Primer columna
print(df.values[:,1]) #Segunda columna
print(df.values[:,-1]) #Última columna 
print(df.values[:,-2]) #Penúltima columna

print(df.values[0,:]) #Primer renglón
print(df.values[1,:]) #Segundo renglón
print(df.values[-1,:]) #Último renglón
# Out:
# [7.4 7.8 7.8 ... 6.3 5.9 6. ]
# [0.7   0.88  0.76  ... 0.51  0.645 0.31 ]
# [5. 5. 5. ... 6. 5. 6.]
# [ 9.4  9.8  9.8 ... 11.  10.2 11. ]
# [ 7.4     0.7     0.      1.9     0.076  11.     34.      0.9978  3.51
#   0.56    9.4     5.    ]
# [ 7.8     0.88    0.      2.6     0.098  25.     67.      0.9968  3.2
#   0.68    9.8     5.    ]
# [ 6.       0.31     0.47     3.6      0.067   18.      42.       0.99549
#   3.39     0.66    11.       6.     ]

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
#print( df.values[:,2:4] ) # Columnas 2, 3
#print( df.values[:,0:5] ) # Columnas 0,1,2,3,4

print( df.values[:5,:] ) # Renglones 0,1,2,3,4
print( df.values[0:5,:] ) # Renglones 0,1,2,3,4

print( df.values[:,-2:]) #Últimas dos columnas
# Out:
# [[7.400e+00 7.000e-01 0.000e+00 1.900e+00 7.600e-02 1.100e+01 3.400e+01
#   9.978e-01 3.510e+00 5.600e-01 9.400e+00 5.000e+00]
#  [7.800e+00 8.800e-01 0.000e+00 2.600e+00 9.800e-02 2.500e+01 6.700e+01
#   9.968e-01 3.200e+00 6.800e-01 9.800e+00 5.000e+00]
#  [7.800e+00 7.600e-01 4.000e-02 2.300e+00 9.200e-02 1.500e+01 5.400e+01
#   9.970e-01 3.260e+00 6.500e-01 9.800e+00 5.000e+00]
#  [1.120e+01 2.800e-01 5.600e-01 1.900e+00 7.500e-02 1.700e+01 6.000e+01
#   9.980e-01 3.160e+00 5.800e-01 9.800e+00 6.000e+00]
#  [7.400e+00 7.000e-01 0.000e+00 1.900e+00 7.600e-02 1.100e+01 3.400e+01
#   9.978e-01 3.510e+00 5.600e-01 9.400e+00 5.000e+00]]
# [[7.400e+00 7.000e-01 0.000e+00 1.900e+00 7.600e-02 1.100e+01 3.400e+01
#   9.978e-01 3.510e+00 5.600e-01 9.400e+00 5.000e+00]
#  [7.800e+00 8.800e-01 0.000e+00 2.600e+00 9.800e-02 2.500e+01 6.700e+01
#   9.968e-01 3.200e+00 6.800e-01 9.800e+00 5.000e+00]
#  [7.800e+00 7.600e-01 4.000e-02 2.300e+00 9.200e-02 1.500e+01 5.400e+01
#   9.970e-01 3.260e+00 6.500e-01 9.800e+00 5.000e+00]
#  [1.120e+01 2.800e-01 5.600e-01 1.900e+00 7.500e-02 1.700e+01 6.000e+01
#   9.980e-01 3.160e+00 5.800e-01 9.800e+00 6.000e+00]
#  [7.400e+00 7.000e-01 0.000e+00 1.900e+00 7.600e-02 1.100e+01 3.400e+01
#   9.978e-01 3.510e+00 5.600e-01 9.400e+00 5.000e+00]]
# [[ 9.4  5. ]
#  [ 9.8  5. ]
#  [ 9.8  5. ]
#  ...
#  [11.   6. ]
#  [10.2  5. ]
#  [11.   6. ]]

# %% [markdown]
# ## Métricas

# %%
var = 0
print( df.columns[var])
columna = df.values[:,var]
print('Minimo',np.min(columna))
print('Maximo',np.max(columna))
print('Promedio',np.mean(columna))
print('Varianza',np.var(columna))
print('Desv estándar',np.std(columna))
print('Mediana',np.median(columna))
print('Q0 Cuartil 0',np.quantile(columna,0.0))
print('Q1 Cuartil 1',np.quantile(columna,0.25))
print('Q2 Cuartil 2',np.quantile(columna,0.5))
print('Q3 Cuartil 3',np.quantile(columna,0.75))
print('Q4 Cuartil 4',np.quantile(columna,1.0))
q3 = np.quantile(columna,0.75)
q1 = np.quantile(columna,0.25)
IQR = q3-q1
print('Rango intercuartil IQR Q3-Q1', IQR)
print('Atipico  < Q1 - 1.5*IQR', q1 - 1.5*IQR)
print('Atipico  > Q3 + 1.5*IQR', q3 + 1.5*IQR)
# Out:
# fixed acidity
# Minimo 4.6
# Maximo 15.9
# Promedio 8.31963727329581
# Varianza 3.0295205688671114
# Desv estándar 1.7405518001102729
# Mediana 7.9
# Q0 Cuartil 0 4.6
# Q1 Cuartil 1 7.1
# Q2 Cuartil 2 7.9
# Q3 Cuartil 3 9.2
# Q4 Cuartil 4 15.9
# Rango intercuartil IQR Q3-Q1 2.0999999999999996
# Atipico  < Q1 - 1.5*IQR 3.95
# Atipico  > Q3 + 1.5*IQR 12.349999999999998

# %% [markdown]
# ## Gráficas

# %%
import matplotlib.pyplot as plt

# %%
var = 0
print( df.columns[var])
columna = df.values[:,var]

plt.figure()
plt.hist(columna,bins=40)
plt.show()

plt.figure()
plt.boxplot(columna)
plt.show()
# Out:
# fixed acidity

# %%
for var in range(0,12):
    columna = df.values[:,var]

    plt.figure()
    plt.suptitle(df.columns[var])
    plt.subplot(1,2,1)
    plt.hist(columna,bins=40)
    plt.subplot(1,2,2)
    plt.boxplot(columna)
    plt.show()

# %%
var1 = 0
var2 = 1
columna1 = df.values[:,var1]
columna2 = df.values[:,var2]

print('Covarianza:',np.cov(columna1,columna2)[0,1],np.cov(columna1,columna2))
print('Correlación:',np.corrcoef(columna1,columna2)[0,1],np.corrcoef(columna1,columna2))
corr = np.corrcoef(columna1,columna2)[0,1]
plt.figure()
plt.title('Corr:'+str(corr))
plt.xlabel(df.columns[var1])
plt.ylabel(df.columns[var2])
plt.plot(columna1,columna2,'.')
plt.show()
# Out:
# Covarianza: -0.07985141683514649 [[ 3.03141639 -0.07985142]
#  [-0.07985142  0.03206238]]
# Correlación: -0.25613089477038203 [[ 1.         -0.25613089]
#  [-0.25613089  1.        ]]

# %%
for var1 in range(0,12):
    for var2 in range(var1+1,12):
        columna1 = df.values[:,var1]
        columna2 = df.values[:,var2]

        corr = np.corrcoef(columna1,columna2)[0,1]
        plt.figure()
        plt.title('Corr:'+str(corr))
        plt.xlabel(df.columns[var1])
        plt.ylabel(df.columns[var2])
        plt.plot(columna1,columna2,'.')
        plt.show()
